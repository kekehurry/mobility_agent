# %% [markdown]
# # Mode Preference Modelling

# %%
from mobility_agent.graph import BehaviorGraph
graph = BehaviorGraph()

profile = "a young women"
desire = "eat"
time = 8
subgraph,weights = graph.preference_modelling(profile=profile,desire=desire,time=time)
graph.visualize_graph(subgraph)
print("Transportation Mode Preference:",weights)
# Out:
# Transportation Mode Preference: [{'primary_mode': 'private_auto', 'duration_minutes': '0-10', 'weight': 0.066836746920696}, {'primary_mode': 'walking', 'duration_minutes': '20-20', 'weight': 0.09036203583495142}, {'primary_mode': 'walking', 'duration_minutes': '10-20', 'weight': 0.14904667660725335}, {'primary_mode': 'walking', 'duration_minutes': '0-10', 'weight': 0.22111320453523675}, {'primary_mode': 'walking', 'duration_minutes': '10-10', 'weight': 0.014929594838490358}, {'primary_mode': 'public_transit', 'duration_minutes': '10-20', 'weight': 0.0665388887287518}, {'primary_mode': 'biking', 'duration_minutes': '0-10', 'weight': 0.21309591190038052}, {'primary_mode': 'auto_passenger', 'duration_minutes': '0-10', 'weight': 0.09495079572786995}, {'primary_mode': 'walking', 'duration_minutes': '20-30', 'weight': 0.07050313828687482}, {'primary_mode': 'walking', 'duration_minutes': '30-40', 'weight': 0.012623006619495034}]

# %% [markdown]
# # Agent-based Modelling

# %% [markdown]
# ### Generate Profile

# %% [markdown]
# - The agent generate realistic profiles based on demongraphic data
# - It then choose a random location as home wighted by cencus block population

# %%
from mobility_agent.agent import MobilityAgent

agent = MobilityAgent(city="Cambridge,MA")
print("Profile:",agent.profile)
print("Home:", agent.memory_locations)
# Out:
# Profile: {
#   "name": "Melanie Rose",
#   "city": "Cambridge,MA",
#   "age": 45,
#   "gender": "female",
#   "employment_status": "not_in_labor_force",
#   "education": "bachelor's_degree",
#   "household_size": 1,
#   "household_income": "75k-100k",
#   "available_vehicles": "1"
# }
#
# Home: {'home': {'name': 'home', 'coordinates': (42.37093658487144, -71.08946539157719)}}

# %% [markdown]
# ### Create Time Schedule
#
# - The agent first creates a full-day activity plan.
#
# - For each activity, it searches for nearby points of interest (POIs) based on their profile, and prefered mode of transportation.
#
# - It then selects the most suitable POI to visit and save it to the working meomory of the agent.
#
# - The agent will save important locations such as home, work, school to `agent.memory_locations`

# %%
agent.get_time_schedule()
agent.time_schedule
# Out:
# [{'start_time': '07:08',
#   'desire': 'school',
#   'transportation': {'mode': 'walking', 'duration': '0-10'},
#   'destination': {'name': 'Kennedy Longfellow',
#    'distance_km': 0.26974996912012444,
#    'coordinates': ('42.369535', '-71.086791')}},
#  {'start_time': '06:41',
#   'desire': 'social',
#   'transportation': {'mode': 'walking', 'duration': '0-10'},
#   'destination': {'name': 'Fairlane Properties',
#    'distance_km': 0.4468984891519462,
#    'coordinates': ('42.373589', '-71.093545')}},
#  {'start_time': '12:33',
#   'desire': 'eat',
#   'transportation': {'mode': 'private_auto', 'duration': '0-10'},
#   'destination': {'name': 'Souper Roll Up Cafe',
#    'distance_km': 0.13456006055527306,
#    'coordinates': ('42.372072', '-71.088896')}},
#  {'start_time': '13:07',
#   'desire': 'home',
#   'transportation': {'mode': 'walking', 'duration': '0-10'},
#   'destination': {'name': 'home',
#    'distance_km': 0.0,
#    'coordinates': (42.37093658487144, -71.08946539157719)}},
#  {'start_time': '13:45',
#   'desire': 'recreation',
#   'transportation': {'mode': 'private_auto', 'duration': '0-10'},
#   'destination': {'name': 'Ahern Field',
#    'distance_km': 0.3537565026244413,
#    'coordinates': ('42.36864', '-71.08649')}},
#  {'start_time': '14:52',
#   'desire': 'social',
#   'transportation': {'mode': 'auto_passenger', 'duration': '0-10'},
#   'destination': {'name': 'rent24 Coworking Cambridge',
#    'distance_km': 0.25179477053941957,
#    'coordinates': ('42.371769', '-71.086622')}},
#  {'start_time': '14:57',
#   'desire': 'home',
#   'transportation': {'mode': 'walking', 'duration': '0-10'},
#   'destination': {'name': 'home',
#    'distance_km': 0.0,
#    'coordinates': (42.37093658487144, -71.08946539157719)}},
#  {'start_time': '15:12',
#   'desire': 'shop',
#   'transportation': {'mode': 'private_auto', 'duration': '0-10'},
#   'destination': {'name': "Albert's Market",
#    'distance_km': 0.2174074128815356,
#    'coordinates': ('42.371765', '-71.087074')}},
#  {'start_time': '15:00',
#   'desire': 'home',
#   'transportation': {'mode': 'walking', 'duration': '0-10'},
#   'destination': {'name': 'home',
#    'distance_km': 0.0,
#    'coordinates': (42.37093658487144, -71.08946539157719)}},
#  {'start_time': '15:43',
#   'desire': 'shop',
#   'transportation': {'mode': 'private_auto', 'duration': '0-10'},
#   'destination': {'name': "Albert's Market",
#    'distance_km': 0.2174074128815356,
#    'coordinates': ('42.371765', '-71.087074')}},
#  {'start_time': '16:53',
#   'desire': 'eat',
#   'transportation': {'mode': 'walking', 'duration': '0-10'},
#   'destination': {'name': '9Zaab',
#    'distance_km': 0.3241424294678566,
#    'coordinates': ('42.371948', '-71.085774')}},
#  {'start_time': '17:53',
#   'desire': 'shop',
#   'transportation': {'mode': 'private_auto', 'duration': '0-10'},
#   'destination': {'name': "Albert's Market",
#    'distance_km': 0.2174074128815356,
#    'coordinates': ('42.371765', '-71.087074')}},
#  {'start_time': '19:45',
#   'desire': 'eat',
#   'transportation': {'mode': 'private_auto', 'duration': '0-10'},
#   'destination': {'name': 'Portugalia',
#    'distance_km': 0.1683496407770619,
#    'coordinates': ('42.372326', '-71.088649')}},
#  {'start_time': '20:30',
#   'desire': 'home',
#   'transportation': {'mode': 'walking', 'duration': '0-10'},
#   'destination': {'name': 'home',
#    'distance_km': 0.0,
#    'coordinates': (42.37093658487144, -71.08946539157719)}}]

# %%
agent.working_memory
# Out:
# ['Today is a normal weekday',
#  'On 07:08, I want to school, I go to Kennedy Longfellow by walking which takes 0-10 minutes.',
#  'On 06:41, I want to social, I go to Fairlane Properties by walking which takes 0-10 minutes.',
#  'On 12:33, I want to eat, I go to Souper Roll Up Cafe by private_auto which takes 0-10 minutes.',
#  'On 13:07, I want to home, I go to home by walking which takes 0-10 minutes.',
#  'On 13:45, I want to recreation, I go to Ahern Field by private_auto which takes 0-10 minutes.',
#  'On 14:52, I want to social, I go to rent24 Coworking Cambridge by auto_passenger which takes 0-10 minutes.',
#  'On 14:57, I want to home, I go to home by walking which takes 0-10 minutes.',
#  "On 15:12, I want to shop, I go to Albert's Market by private_auto which takes 0-10 minutes.",
#  'On 15:00, I want to home, I go to home by walking which takes 0-10 minutes.',
#  "On 15:43, I want to shop, I go to Albert's Market by private_auto which takes 0-10 minutes.",
#  'On 16:53, I want to eat, I go to 9Zaab by walking which takes 0-10 minutes.',
#  "On 17:53, I want to shop, I go to Albert's Market by private_auto which takes 0-10 minutes.",
#  'On 19:45, I want to eat, I go to Portugalia by private_auto which takes 0-10 minutes.',
#  'On 20:30, I want to home, I go to home by walking which takes 0-10 minutes.']

# %%
agent.memory_locations
# Out:
# {'home': {'name': 'home',
#   'coordinates': (42.37093658487144, -71.08946539157719)},
#  'school': {'name': 'Kennedy Longfellow',
#   'coordinates': ('42.369535', '-71.086791'),
#   'category': ''}}
